# %% [markdown]
# # traceback-coach — features tour
#
# This notebook showcases the key features of traceback-coach. A central insight:
# when you re-run the **same error**, the coach message fades from full detail (with
# diagram and worked example) → brief summary → minimal hint. You can force it back
# with `%coach_level`, track what you've learned with `%coach_stats`, and keep learning
# with `%coach_watch` and `%coach_lesson`.

# %%
# %load_ext traceback_coach

# %% [markdown]
# ## Progressive fade — run the SAME error three times

# %%
# %%coach
# print(total)

# %%
# %%coach
# print(total)

# %%
# %%coach
# print(total)

# %% [markdown]
# ## Force the detail level back

# %%
# %coach_level full

# %% [markdown]
# ## Your error stats

# %%
# %coach_stats

# %% [markdown]
# ## Watch mode + lessons

# %%
# %coach_watch on

# %%
xs = [1, 2, 3]
xs[7]

# %%
# %coach_lesson ZeroDivisionError

# %% [markdown]
# ## Guess the error first (active recall)
#
# Turn on quiz mode, then run a broken cell. Predict the error **type** before you reveal the Coach's analysis — recalling first helps it stick.

# %%
# %coach_quiz on

# %%
# %%coach
# print(mystery)

# %% [markdown]
# Click **Reveal the Coach's analysis** to check your guess. Turn it off again with `%coach_quiz off`.

# %% [markdown]
# ## Bilingual mode — Traditional Chinese (zh-HK)
#
# Switch the interface to zh, trigger a NameError, then switch back to en.

# %%
# %coach_lang zh

# %%
# %%coach
# print(zh_demo_undef)

# %%
# %coach_lang en
