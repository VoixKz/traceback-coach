# %% [markdown]
# # Lesson 1 — Names & Types
#
# Run each cell. When it breaks, read the Coach's card: it explains the error, shows where it came from, and asks you a question instead of giving the fix. Try to fix it yourself, then re-run.

# %%
# %load_ext traceback_coach

# %% [markdown]
# ## 1. A name Python doesn't know (NameError)
#
# You try to print a total you never created.

# %%
# %%coach
# print(total)

# %% [markdown]
# **Your turn:** create `total` (e.g. `total = 0`) above the print, then re-run.

# %% [markdown]
# ## 2. Mixing text and numbers (TypeError)
#
# `age` is text, and you add a number to it.

# %%
# %%coach
# age = "5"
# print(age + 1)

# %% [markdown]
# **Your turn:** convert first — `int(age) + 1` — and re-run. What did the Coach's question point you to?
