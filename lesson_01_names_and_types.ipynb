# %% [markdown]
# # 📖 Lesson 1 · Names & Types
#
# Two of the most common errors in Python are **NameError** (using a variable before you create it) and **TypeError** (mixing incompatible types). This lesson gives you one broken cell each to read, then a prompt to fix it yourself.
#
# **How to run:** **Kernel → Restart Kernel and Run All Cells**, or **Shift+Enter** through it.
#
# > The Coach **never shows the fix** — it teaches you to read the error yourself.
#
# **How to use this lesson:** read the error, understand *why* it broke, then fix it yourself.

# %% [markdown]
# ## 0 · Load the extension

# %%
# %load_ext traceback_coach

# %% [markdown]
# ## 1 · 🏷️ A name Python doesn't know — NameError
#
# You try to print a running total you never actually created. The Coach will explain *which* name is unknown and *why* Python can't find it.

# %%
# %%coach
# print(total)

# %% [markdown]
# **Your turn:** add `total = 0` on a new line *above* the `print`, then re-run the cell.
#
# *Hint from the Coach card: which name triggered the error? Was it ever assigned?*

# %% [markdown]
# ## 2 · 🔢 Mixing text and numbers — TypeError
#
# `age` holds the string `"5"`, not the integer `5`. Adding a number to a string isn't allowed in Python — the Coach will point out the two types that clashed.

# %%
# %%coach
# age = "5"
# print(age + 1)

# %% [markdown]
# **Your turn:** convert first — change `age + 1` to `int(age) + 1` — then re-run.
#
# *Hint from the Coach card: what were the two types that clashed? Which function converts a string to an integer?*

# %% [markdown]
# ---
# Good work — you've read two of the most common Python errors and fixed them yourself. That skill transfers to every error you'll ever see.
