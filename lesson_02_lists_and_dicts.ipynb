# %% [markdown]
# # Lesson 2 — Lists & Dictionaries
#
# Run each cell, read the Coach's card, and try to fix it yourself before moving on.

# %%
# %load_ext traceback_coach

# %% [markdown]
# ## 1. A position that doesn't exist (IndexError)
#
# The list has 3 items, but you ask for the 4th.

# %%
# %%coach
# scores = [88, 92, 79]
# print(scores[3])

# %% [markdown]
# **Your turn:** remember indices start at 0 — the last valid index is `len(scores) - 1`. Fix and re-run.

# %% [markdown]
# ## 2. A key that isn't there (KeyError)
#
# The dictionary has no key `"math"`.

# %%
# %%coach
# grades = {"cs": 90}
# print(grades["math"])

# %% [markdown]
# **Your turn:** check the keys the dict actually has, or use `grades.get("math")`. Re-run and read the Coach's question.
