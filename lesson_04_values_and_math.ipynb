# %% [markdown]
# # Lesson 4 — Values & Math
#
# Sometimes the type is right but the VALUE is wrong, or the math is impossible. Run each cell and read the Coach's card.

# %%
# %load_ext traceback_coach

# %% [markdown]
# ## 1. Right type, wrong value (ValueError)
#
# `int()` accepts strings, but only ones that look like numbers.

# %%
# %%coach
# n = int("ten")
# print(n)

# %% [markdown]
# **Your turn:** pass digits like `"10"`, or validate the input first. Re-run.

# %% [markdown]
# ## 2. Dividing by zero (ZeroDivisionError)
#
# The divisor `count` is 0 when the division runs.

# %%
# %%coach
# count = 0
# average = 100 / count
# print(average)

# %% [markdown]
# **Your turn:** check `count != 0` before dividing. Re-run and read the Coach's question.
